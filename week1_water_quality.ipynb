# %%
# Week 1 - Water Quality Prediction Project

# Step 1: Import Libraries
import pandas as pd

# Step 2: Load Dataset
# (Upload the dataset file manually in Colab OR place it in your repo later)
# You can download from: https://www.kaggle.com/datasets/adityakadiwal/water-potability
# For now, let's simulate with sample dataset
# url = "https://raw.githubusercontent.com/dphi-official/Datasets/master/water_potability.csv"
# data = pd.read_csv(url)

# Load the dataset from the uploaded file
file_path = "water_potability.csv"  # Make sure the filename matches the uploaded file
data = pd.read_csv(file_path)

# Step 3: Explore Dataset
print("First 5 rows of dataset:")
print(data.head())

print("\nDataset Info:")
print(data.info())

print("\nSummary Statistics:")
print(data.describe())

print("\nMissing Values in Each Column:")
print(data.isnull().sum())

# Step 4: Problem Statement
problem_statement = """
Problem Statement:
We aim to predict whether water is potable (safe for drinking) based on chemical properties
such as pH, hardness, solids, chloramines, sulfate, conductivity, organic carbon,
trihalomethanes, turbidity, etc.
This helps in sustainable water management and supports UN SDG Goal 6: Clean Water & Sanitation.
"""
print(problem_statement)
# Out:
# First 5 rows of dataset:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
# ...
